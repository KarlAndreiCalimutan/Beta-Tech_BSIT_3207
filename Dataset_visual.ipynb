# %% [markdown]
# <a href="https://colab.research.google.com/github/mushimushe/Beta-Tech_BSIT_3207/blob/main/Dataset_visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/mushimushe/Beta-Tech_BSIT_3207/main/Data%20Visualizations/Datasets%20csv/Total%20Damages%20Line%20Chart.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#                             COUNTRY       DAMAGES
# 0                       Timor-Leste        20,940
# 1                           Myanmar       140,343
# 2  Lao People's Democratic Republic    152,227.00
# 3                          Cambodia     1,323,122
# 4                          Malaysia     1,678,845
# 5                       Philippines     3,697,501
# 6                         Indonesia  8,452,649.00
# 7                           Vietnam    11,508,245
# 8                          Thailand    53,538,490

# %%
#Visualization
#getting all values from the dataframe/csv
COUNTRY = df["COUNTRY"]
DAMAGES = df["DAMAGES"]

#changing the size of the entire graph
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)

#Changing the background color of the graph
plt.rcParams['axes.facecolor'] = '#F2F2F2'

#Creating plots
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("\n Flood Damages in Asean Country", fontweight="bold", fontsize=20)
plt.xlabel("COUNTRY", fontsize=15)
plt.ylabel("DAMAGES", fontsize=15)
plt.grid(color = 'white', linestyle = '--', linewidth = 1.5)
plt.plot(COUNTRY, DAMAGES, 'o-', lw=2.4, c='#E33B3A')
plt.legend(labels=['DAMAGES'])
plt.show()

# %%
url = 'https://raw.githubusercontent.com/mushimushe/Beta-Tech_BSIT_3207/main/Data%20Visualizations/Datasets%20csv/Bar%20chart%20line%20graph%20total%20deaths%20in%2020%20year.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#        Country  Deaths
# 0     Cambodia     934
# 1    Indonesia    1823
# 2          Lao      43
# 3     Malaysia     160
# 4      Myanmar     305
# 5  Philippines     838
# 6     Thailand    2247
# 7  Timor Leste       3
# 8      Vietnam    2412

# %%
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(7)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
# Plot the data using bar() method
plt.bar(X, Y, color='g')
plt.title("Deaths over 20 Years")
plt.xlabel("Years")
plt.ylabel("Number of Deaths")
  
# Show the plot
plt.show()

# %%
url = 'https://raw.githubusercontent.com/mushimushe/Beta-Tech_BSIT_3207/main/Data%20Visualizations/Datasets%20csv/Bar%20chart%20line%20graph%20total%20deaths%20in%2020%20year.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#        Country  Deaths
# 0     Cambodia     934
# 1    Indonesia    1823
# 2          Lao      43
# 3     Malaysia     160
# 4      Myanmar     305
# 5  Philippines     838
# 6     Thailand    2247
# 7  Timor Leste       3
# 8      Vietnam    2412

# %%
#Visualization
#getting all values from the dataframe/csv
Country = df["Country"]
Deaths = df["Deaths"]

#changing the size of the entire graph
f = plt.figure(tight_layout=True)
f.set_figwidth(23)
f.set_figheight(10)

#Changing the background color of the graph
plt.rcParams['axes.facecolor'] = '#F2F2F2'

#Creating plots
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title("\n Flood Death Rate in Asean Country", fontweight="bold", fontsize=20)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Death Count", fontsize=15)
plt.grid(color = 'white', linestyle = '--', linewidth = 1.5)
plt.plot(Country, Deaths, 'o-', lw=2.4, c='#E33B3A')
plt.legend(labels=['Death Rate'])
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/mushimushe/Beta-Tech_BSIT_3207/blob/main/Dataset_visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/mushimushe/Beta-Tech_BSIT_3207/main/Data%20Visualizations/Datasets%20csv/Total%20Damages%20Line%20Chart.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#                             COUNTRY       DAMAGES
# 0                       Timor-Leste        20,940
# 1                           Myanmar       140,343
# 2  Lao People's Democratic Republic    152,227.00
# 3                          Cambodia     1,323,122
# 4                          Malaysia     1,678,845
# 5                       Philippines     3,697,501
# 6                         Indonesia  8,452,649.00
# 7                           Vietnam    11,508,245
# 8                          Thailand    53,538,490

# %%
#getting all the values stored in the dataframe/csv
DAMAGES = df['DAMAGES']
COUNTRY = df['COUNTRY']
#changing the size of visualization
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(7)

#creating the plot
plt.plot(COUNTRY, DAMAGES, 'o-', color ="#FF0075", linewidth = 2)
plt.title("Total Damages in Asean Country (2000-2020)", fontweight="bold")
plt.xlabel("COUNTRY")
plt.ylabel("DAMAGES")
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
url = 'https://raw.githubusercontent.com/mushimushe/Beta-Tech_BSIT_3207/main/Data%20Visualizations/Datasets%20csv/Bar%20chart%20line%20graph%20total%20deaths%20in%2020%20year.csv'
df = pd.read_csv(url)
display(df.iloc[0:])
# Out:
#        Country  Deaths
# 0     Cambodia     934
# 1    Indonesia    1823
# 2          Lao      43
# 3     Malaysia     160
# 4      Myanmar     305
# 5  Philippines     838
# 6     Thailand    2247
# 7  Timor Leste       3
# 8      Vietnam    2412

# %%
f = plt.figure()
f.set_figwidth(13)
f.set_figheight(7)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 1])
  
# Plot the data using bar() method
plt.bar(X, Y, color='g')
plt.title("Deaths over 20 Years")
plt.xlabel("Years")
plt.ylabel("Number of Deaths")
  
# Show the plot
plt.show()
